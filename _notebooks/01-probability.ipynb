# %% [markdown]
# # Probability and an Introduction to Jupyter, Python and Pandas

# %% [markdown]
# **Abstract**: In this first session we will introduce *machine
# learning*, review *probability* and begin familiarization with the
# Jupyter notebook, python and pandas.

# %% [markdown]
# $$
# $$

# %% [markdown]
# -   See probability review at end of slides for reminders.
#
# -   For other material in Bishop read:
#
# -   If you are unfamiliar with probabilities you should complete the
#     following exercises:
#
# \thanks
