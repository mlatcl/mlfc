# %% [markdown]
# # MPhil Preliminary Assessment
#
# ### 4th January 2023
#
# ### Neil D. Lawrence
#
# This notebook is a helper for reviewing MPhil applications

# %%
import referia as rf
# Out:
# /Users/neil/opt/anaconda3/envs/py311/lib/python3.11/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
rf.display.expand_cell()
# Out:
# <style>
# .container {
#     width: 100% !important;
# }
#
# div.notebook-container {
#     width: 100% !important;
#     height: fit-content;
# }
#
# div.menubar-container {
#     width: 100% !important;
#     height: fit-content;
# }
#
# div.maintoolbar-container {
#     width: 100% !important;
#     height: fit-content;
# }
#
# div.cell.selected {
#     border-left-width: 1px !important;
# }
#
# div.output_scroll {
#     resize: vertical !important;
# }
#
# .output_wrapper .output {
#     overflow-y: visible;
#     height: fit-content;
# }
#
#
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
data = rf.assess.Data()
index = data.index[0]

# %%
scorer=rf.display.Scorer(index, data)
scorer.run()
# Out:
# Dropdown(options=('Liu_Zhi_Yu', 'Oladele_Kamal_Gbolahon', 'Moreno_Raja_Mehta', 'Newman_Thomas_Zed', 'Gao_Xiang…
# HTMLMath(value='', description=' ')
# HTMLMath(value='', description=' ')
# Button(description='Reload Flows', style=ButtonStyle())
# Text(value='', description='Candidate Email', layout=Layout(width='300px'))
# HTMLMath(value='', description=' ')
# HTMLMath(value='<h3>Preliminary Research</h3>\n<ul>\n<li>A short proposal outlining what the applicant plans t…
# Textarea(value='', description='Comment', layout=Layout(width='800px'))
# HTMLMath(value='<h3>Preliminary Degree</h3>\n<ul>\n<li>A quick overview of their current degree.</li>\n</ul>',…
# Textarea(value='', description='Comment', layout=Layout(width='800px'))
# HTMLMath(value='<h3>Preliminary Score</h3>\n<h4>FAQ on Scoring</h4>\n<ul>\n<li>How do I choose the correct pre…
# Textarea(value='', description='Comment', layout=Layout(width='800px'))
# ...

# %%
data._column_name_map
# Out:
# {'Application Number': 'applicationId',
#  'givenName': 'givenName',
#  'preferredName': 'preferredName',
#  'familyName': 'familyName',
#  'Preliminary Comment': 'preliminaryComment',
#  'Preliminary Score': 'preliminaryScore',
#  'Other Comment': 'otherComment',
#  'Candidate Email': 'candidateEmail',
#  'index': 'index',
#  'interviewOrder': 'interviewOrder',
#  'applicationUrl': 'applicationUrl',
#  'panelUrl': 'panelUrl',
#  'jamboardUrl': 'jamboardUrl',
#  'reportUrl': 'reportUrl',
#  'ApplicationPDF': 'ApplicationPDF',
#  'Preliminary Research Comment': 'preliminaryResearchComment',
#  'Preliminary Overall Comment': 'preliminaryOverallComment',
#  'Preliminary Overall Score': 'preliminaryOverallScore',
#  'Comment 2': 'comment2',
#  '_Preliminary Research Criterion': '_preliminaryResearchCriterion',
#  '_Preliminary Degree Criterion': '_preliminaryDegreeCriterion',
#  'Preliminary Degree Comment': 'preliminaryDegreeComment',
# ...
