# %% [markdown]
# # Data in Python

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Naive Approach

# %% [markdown]
# ## Databases
#
# You should already know this from previous courses, but here's a little recap.
#
# A database is not a special piece of hardware, it can live on any medium.
#
# [example of paper searchable database, dictionary, logs]

# %% [markdown]
# ### SQL in Python

# %%
# best practices, credential storage, environment variables

# %% [markdown]
# ## Pandas

# %% [markdown]
# ### Other advantages:

# %% [markdown]
# #### In-memory
# In-memory perations naturally outpace on-disk operations.

# %%
# read file, calculate average overall rating,
# vs just calculate it after it's in memory

# %% [markdown]
# #### C++
# Moving many operations to numpy, which in turn moves it to C++.

# %%
# example speed numpy vs python list

# %% [markdown]
# #### Usability
#
# Under the hood functions to handle many data formats and types.

# %%
# example reading excel file, date conversion

# %% [markdown]
# pd.apply

# %% [markdown]
# #### Pickles

# %%
# pickle vs csv

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### Math background

# %%
# indexes are a thing in SQL, Pandas, python dictionaries

# %% [markdown]
# ### Practical example

# %%
# speed comparison in pandas

# %%
# speed comparison in SQL

# %% [markdown]
# ### Multiindex

# %%
# multiindex
# find players with good speed and strength

# %% [markdown]
# ## Alternatives

# %% [markdown]
# #### Parquet

# %%
# compare speed vs pickle, csv

# %% [markdown]
# #### Polars

# %%
# compare speed vs pandas

# %% [markdown]
# ## Remote

# %% [markdown]
# #### AWS Relational Databases

# %%
# aws example code but not run

# %% [markdown]
# #### Storage

# %%
# google drive example
# s3 example but not run

# %% [markdown]
# ## Debugging

# %% [markdown]
# Worked examples: we have a simple-ish data science system, let's see what is our issue, and how to fix it.
#
# Example 1: no index, slow lookup
#
# Example

# %%
# worke

# %% [markdown]
# ## TL;DR

# %% [markdown]
# - Know/remember what ways of storing and operating on data are out there
# - Choose the right approach, estimate the tradeoffs
# - Know how to code it up
# - Know how to debug
